# %%
# !apt install tesseract-ocr
# !apt install libtesseract-dev

# %%
# !pip install pytesseract

# %%
# !pip install opencv-python

# %%
import pytesseract
from PIL import Image
from io import BytesIO
import cv2
import numpy as np

# %%
#poppler_path=r'C:/Users/sivaram salivahan/Desktop/Siva Python/Project/poppler-0.68.0_x86/poppler-0.68.0\bin'

# %%
from pdf2image import convert_from_path

# %%
pdfs = r"report.pdf"
pages = convert_from_path(pdfs,poppler_path=r'C:/Users/sivaram salivahan/Desktop/Siva Python/Project/poppler-0.68.0_x86/poppler-0.68.0\bin')

i = 1
for page in pages:
    image_name = "Page_" + str(i) + ".jpg"  
    page.save(image_name, "JPEG")
    i = i+1

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
image  = Image.open('page_1.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1700x2200 at 0x23BB5EE05E0>

# %%
print(pytesseract.image_to_string(image,lang='eng'))
# Out:
#
#
#
# Page - of Pages New York State Department of Motor Vehicles
#
# POLICE pict oel pePORT
# Pee “ow cory
#
# Day of Week Military Time . No. Injured
#
#
#
#
#
#
#
# VEHICLE 1 O VEHICLE 2
#
# VEHICLE 1 - Driver~ State of Lic. | VEHICLE 2 - Driver
# License ID Number
#
# Driver Name -exactly Driver Name - exactly
# as printed on license as printed on license
#
# ‘Address (Include Number & Street) | Address (Include Number & Street) a |
#
#
#
#
#
#
#
# City or Town State Zip Code City or Town State Zip Code
#
# Unlicensed | No. of ate of Bir Unlicensed =| No. of Public
# Day Year Occupants M Occupants Property
# Damaged SS
# Name-exactly as printed on registration ate of Birth
# Sp"
#
# Address (Include Number & Street) Apt. No, | Haz. leleased || Address (/nclude Number & Streef) Haz. {Released
#
# Mat Mat. oOo
#
# Code Code
#
# City or Town State Zip Code Gity or Town Zip Code
#
# ...
